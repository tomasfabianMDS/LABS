# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Catherine Benavides
# - Ayudante: Nicolás Ojeda, Eduardo Moya

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Tomás Guzmán
# - Nombre de alumno 2: Fabián Palma

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/tomasfabianMDS/LABS.git

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 7 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos Y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquer material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# 1. Git es un sistema de control de versiones distribuido, el cual está diseñado principalmente para coordinar versiones de trabajos relacionados con scripts de programación. Esta herramienta permite realizar un seguimiento de los cambios en archivos, lo que facilita el trabajo colaborativo entre varias personas en un mismo proyecto.
# 2. Las 3 principales diferencias:
# 1era: Git es una herramienta de linea de comandos que opera de manera local en la computadora de un usuario, en cambio GitHub es una plataforma en línea que ofrece servicos en la nube para alojar repositorios Git.
# 2da: Github tiene funcionalidades adicionales que git como tal no tiene, estas son: seguimiento de problemas, solicitudes de extracción, gestión de proyectos y wikis.
# 3era: TIenes distintos propósitos, git se utiliza para el control de versiones local y puede utilizarse sin conexión a internet, mientras que GitHub está diseñado específicamente para alojar proyectos en la nube y facilitar la colaboración en línea entre developers
# 3. Un hash es un codigo unico generado a partir de datos de entrada. En Git, se utiliza un hash para identificar de manera única cada 'commit', que representa un conjuntos de cambios en el repositorio.
# 4. La estructura de datos de Git se compone de tres elementos principales:
# Blob (Objeto): Representa un archivo en el repositorio, almacenando el contenido de dicho archivo.
# Tree (Árbol): Representa un directorio en el repositorio y contiene referencias a Blobs y Trees que están dentro de ese directorio.
# Commit (Confirmación): Representa un punto en la historia del repositorio y contiene metadatos como el autor, el mensaje del commit y un enlace al Tree que representa el estado del proyecto en ese momento.
# 5. el comando para crear un repositorio en un directorio seteado es git init.
# el comando para rastrear un archivo los cambios de un archivo es git add archivo.
# el comando para confirmar ciertos cambios que uno hace en un determinado archivo es git commit -m "mensaje descriptivo de los cambios".
# finalmente, para revisar el estado actual del repo se puede ejectuar un git status.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# 6, Falso. Ya que como se verá en lo que sigue de lab, a veces hay archivos que no contienen una estructura 'mergeable' y esto lo manifiesta a traves de warnings llamados conflictos. La solución a estos problemas requiere una intervención manual.
# 7, Falso. 'git pull' no es equivalente a git clone, ya que 'git clone' se utiliza para crear un nuevo repositorio local, mientras que git pull se utiliza para actualizar un repositorio local con los cambios del repositorio remoto.
# 8, Falso. Ya que git status muestra el estado actual del repositorio local, incluyendo cambios en fase staged, archivos modificados y archivos no rastreados. Mientras que git log es un registro de commits en la rama que uno esta parado en la consola(por ej: git bash) incluyendo info del autor, fecha y descripción del commit.
# 9, Verdadero. En git, es posible volver a versiones anteriores del codigo. Un ejemplo de ello es el comando git checkout.
# 10, Falso. El comando git commit se utiliza para consolidar cambios en el repositorio local. El comando para realizar y subir cambios al repositorio remoto es git pull.

# %% [markdown]
# Por último, investigue y comente para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# El comando git stash se utiliza para guardar temporalmente cambios que no están listos para ser confirmados en el repositorio. Esto es útil cuando necesitas cambiar de rama o trabajar en otro aspecto del proyecto sin comprometer los cambios actuales.
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)
# git reset y git revert son dos comandos diferentes que se utilizan para deshacer cambios en Git, pero tienen diferentes efectos y propósitos:
# git reset: Este comando se utiliza para deshacer cambios locales y mover la HEAD (puntero de la rama actual) a un commit específico. Puede ser usado para deshacer cambios no confirmados (en la etapa de trabajo o staged) o para retroceder a versiones anteriores del proyecto. Tiene la capacidad de eliminar permanentemente cambios del historial.
# git revert: Revierte un commit específico creando un nuevo commit que deshace los cambios introducidos por el commit original. A diferencia de git reset, no modifica el historial de commits, sino que agrega un nuevo commit que revierte los cambios. Esto es útil cuando necesitas mantener un historial de cambios completo y no deseas eliminar commits anteriores.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code>
# https://github.com/tommyguzman/tommyguzman.git
# <code>Link Presentacion 2:</code>
# https://github.com/Fabian-P-R/Fabianpr

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>
# el .gitignore que creé se llama archivo.gitignore y contiene lo siguiente:
#
# ### Esto ignora la carpeta de videos
# videos/
# ### Esto ignora todos los archivos .txt
# *.txt
# ### Esto hace la excepcion con el archivo 171.txt
# !texts/171.txt

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Para descubrir el objetivo del proyecto, tuvimos que abrir la carpeta de README.md. Allí encontramos un imagen con animales y con la siguiente frase: "proyecto para emular los sonidos de animales". En cuanto la estructura del proyecto, este cuenta 3 carpetas, la de README.md descrita anteriormente y 2 archivos.py con nombre "animales.py" y "main.py". Animales.py contiene una función llamada animales que toma un parámetro de entrada llamado input. La función imprime un sonido característico dependiendo del animal proporcionado como entrada: "miau" para un gato, "guau" para un perro y una URL de YouTube para un zorro. Si se proporciona un animal que no está reconocido (diferente de gato, perro o zorro), se genera un error de valor. Y en cuanto a main.py, este archivo importa la función animales del archivo animales.py. Luego, verifica si el script main.py está siendo ejecutado directamente como el programa principal. Si es así, solicita al usuario ingresar el nombre de un animal, luego llama a la función animales con el nombre del animal como argumento y muestra lo que dice ese animal, según la función animales definida en el archivo animales.py.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Respecto de los ultimos cambios al repositorio tienen que ver con 3 commits, donde el primero tiene un nombre generico('primer commit') y esta asociado a la rama principal, el segundo commit lleva por nombre "se agrega función" y esta asociado a la rama principal también y el tercer commit lleva por nombre "Se separa el proyecto en modulos" y está asociado tanto a la rama principal como a las ramas origin/new_features, origin/main y origin/HEAD. Esto lo hicimos con el comando git log --oneline --decorate --graph.
# En cuanto a las principales ramas de trabajo, estan las ramas locales de las cuales solo esta main y estan las 3 ramas remotas llamadas fix-ifs, origin/main y new_features. El comando que ocupamos para esto fue git branch -a.
# Respecto de cuan informativos son los commit, bueno el primero no es para nada informativo, mientras que el segundo agrega información respecto de la creación de una función pero no de qué trata esa función y el tercero presenta un problema similar, ya que no se declara información respecto a cuáles y en cuántos módulos es separado el proyecto.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Bueno el comando que utilizamos para explicar el error de código es(estando parados en main) git blame main.py. Ejecutando esto, nos damos cuenta que no hay un elif en la definición de la función animales.py que importa main.py. Para ver quien cometió implementamos un blame en animales.py, ejecutando vemos que el desarrollo de este código estuvo en la manos de mezosky, por lo que él es el responsable del error.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Para el comit `c8b1a62d7299552b0654f930d695b33109214111`, tenemos la agregación de una función al proyecto y se realiza en la rama main en el repositorio local, a diferencia del commit `362fe21ee44f53ee944cee4ba484600308f83d78`, que separa el proyecto en módulos y está asociado tanto a la rama main como a las otras ramas remotas tituladas como  origin/new_features, origin/main y origin/HEAD. Por otro lado, el commit `25543a3baf77292baf849726784ca005473acab1`, este es el commit que corrige problemas relacionados con condicionales ifs y efectivamente esta asociado solo a la rama fix-ifs. Las principales diferencias entre los 3 commits son su mensaje(nombre) y las rams asociadas a él.
# Los comandos que utilicé para realizar la anterior interpretación fueron:
# git log 'codigoDelCommit'

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Realice el merge con el siguiente comando: git merge origin/fix-ifs.
# Lo cual ejecutaba un error al hacer en merge diciendo que estaban tratando de mergear archivos que no eran mergeables.
# Me dió 2 hints: uno me decia que arreglara esta incompatibilidad en el arbol de trabajo y luego hiciera un git add archivo_modificado.py y el segundo me decía que esta modificación la guardara en un commit.
# Creo que la parte que está ocasionando del conflicto es que en el main.py de la rama fix-ifs de la linea 1 a la 14 esta el mismo codigo de animales.py mientras que en el main.py de la rama main/origin se está ahorrando todo ese codigo con from animales import animales.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# La solución parte con la correción del código y decisión con que variante de código dejar. Decidimos dejar el from animales import animales para ahorrar lineas de codigos que ya estan programadas en animales.py. Esto trae como consecuencia que habría que corregir el main.py de la rama fix-ifs. Se borraron las siguientes lineas:
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     elif input.lower() == 'perro':
#         print('guau')
#     elif input.lower() == 'fox':
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')
# Y se puso en su lugar:
# from animales import animales
#
# Luego para consolidar este cambió aplicamos un git add main.py y luego el siguiente commit:
#  $ git commit -m "Se resolvió el conflicto en main.py. Se modificaron las lineas afectadas en afectadas"
# Finalmente se crea la nueva rama:
# git checkout -b solucion-conflicto

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
